# %%
import pandas as pd
import json

# %%
with open('input-dump', 'r') as data:
    next(data)
    dataframe = data.read()
    #df = pd.read_json('input-dump',lines=True, )
    df = pd.DataFrame(pd.read_csv(data,sep='|',header=None).iloc[:,0].apply(ast.literal_eval).tolist())
df.describe()
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# <ipython-input-6-aaa609c81d6e> in <module>
#       3     dataframe = data.read()
#       4     #df = pd.read_json('input-dump',lines=True, )
# ----> 5     df = pd.DataFrame(pd.read_csv(data,sep='|',header=None).iloc[:,0].apply(ast.literal_eval).tolist())
#       6 df.describe()
#
# ...

# %%
df = pd.json_normalize (dataframe[1:])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-31baf95e04e6> in <module>
# ----> 1 dataframe.apply(dict)
#       2 df = pd.json_normalize (dataframe[1:])
#
# AttributeError: 'list' object has no attribute 'apply'
